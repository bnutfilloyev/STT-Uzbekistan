# %%
import pandas as pd
import glob, os

# %%
COMMON_VOICE_PATH = "common-voice-tsv"
os.chdir(COMMON_VOICE_PATH)

# %%
files = []
for file in glob.glob("*.txt"):
    files.append(file)
files
# Out:
# ['dev.txt',
#  'invalidated.txt',
#  'other.txt',
#  'reported.txt',
#  'test.txt',
#  'train.txt']

# %%
with open(files[0], 'r+') as f:
    data = f.readlines()
data
# Out:
# ['Qo‘shimchasi bilan kelgan sanoq sonlar miqdorni donalab sanash yo‘li bilan ko‘rsatadi.\n',
#  'Birlashgan aholining etnik tarkibi xilma-xil bo‘lgan.\n',
#  'Evertonga qarshi maydonga tushayotgan Arsenal o‘tgan turda Sitiga yutqazdi.\n',
#  '"Unga boshqalar ham javob yoza olmaydigan qilib qoʻysin, ammo akkauntni butunlay oʻchirmaslik kerak edi."\n',
#  '"Erkaklarni seving, ayollar."\n',
#  'Zolimlar va ularning qurbonlari tuproq ostida uchrashishadi.\n',
#  'So‘nggi natijalar bugun aniq bo‘lmasligi mumkin.\n',
#  'Argentinadan biror iste’dod chiqib qolsa Maradonaga qiyoslashadi va albatta yangi Maradona shu deyishadi.\n',
#  'Tojik oshxonasining ramzlaridan biriga aylangan qurutob haqida gapirib bergandim.\n',
#  'Lekin qavmim buni bilmaydi.\n',
#  'Senzuraga yo‘l qo‘yilmaydi.\n',
#  'Mashinalar uchun infratuzilma haqida fikrlaganda bir narsani esdan chiqarmaslik kerak.\n',
# ...

# %%
import re
characters = r'; |, |\*|\n|.|\(|\)|\[|\]|\{|\}|\?|!|:|"|\'|\|'
